# %% [markdown]
# <center><h1> <b> Titanic Survival Prediction </b> </h1></center>

# %% [markdown]
# <center> <h3> <b> Main Goal : </b> </h3> <h4> <b> Predicts whether a
# passenger on the Titanic survived or not. </b> </h4> </center>

# %% [markdown]
# <center> <h4> <b> Import necesaary libraries </h4> </b> </center>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <center> <h4> <b> Import dataset </h4> </b> </center>

# %%
df= pd.read_csv('tested.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# <center> <h4> <b> Exploratory data analysis </h4> </b> </center>

# %%
import missingno

missingno.bar(df)
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())
df['Fare'] = df['Fare'].fillna(df['Fare'].mean())

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex       Age  SibSp  \
# 0                                Kelly, Mr. James    male  34.50000      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.00000      1
# 2                       Myles, Mr. Thomas Francis    male  62.00000      0
# 3                                Wirz, Mr. Albert    male  27.00000      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.00000      1
# ..                                            ...     ...       ...    ...
# ...

# %%
Embarked = df['Embarked'].unique()
for Embarkeds in Embarked:
    print("->",Embarkeds)
# Out:
# -> Q
# -> S
# -> C

# %%
df['Embarked'] = df['Embarked'].map( {'Q': 0,'S':1,'C':2}).astype(int)
df['Sex'] = df['Sex'].map( {'female': 1,'male':0}).astype(int)

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex              int32
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked         int32
# dtype: object

# %%
df['Age'] = df['Age'].astype(int)

# %%
df['Fare'] = df['Fare'].astype(int)

# %%
data = df.drop(['PassengerId','Name','Cabin','Ticket'], axis =1, inplace=True)

# %% [markdown]
# <center> <h4> <b> Analyzed dataset </h4> </b> </center>

# %%
df
# Out:
#      Survived  Pclass  Sex  Age  SibSp  Parch  Fare  Embarked
# 0           0       3    0   34      0      0     7         0
# 1           1       3    1   47      1      0     7         1
# 2           0       2    0   62      0      0     9         0
# 3           0       3    0   27      0      0     8         1
# 4           1       3    1   22      1      1    12         1
# ..        ...     ...  ...  ...    ...    ...   ...       ...
# 413         0       3    0   30      0      0     8         1
# 414         1       1    1   39      0      0   108         2
# 415         0       3    0   38      0      0     7         1
# 416         0       3    0   30      0      0     8         1
# 417         0       3    0   30      1      1    22         2
#
# [418 rows x 8 columns]

# %%
df.describe()
# Out:
#          Survived      Pclass         Sex         Age       SibSp       Parch  \
# count  418.000000  418.000000  418.000000  418.000000  418.000000  418.000000
# mean     0.363636    2.265550    0.363636   30.191388    0.447368    0.392344
# std      0.481622    0.841838    0.481622   12.654104    0.896760    0.981429
# min      0.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000    0.000000   23.000000    0.000000    0.000000
# 50%      0.000000    3.000000    0.000000   30.000000    0.000000    0.000000
# 75%      1.000000    3.000000    1.000000   35.750000    1.000000    0.000000
# max      1.000000    3.000000    1.000000   76.000000    8.000000    9.000000
#
#              Fare    Embarked
# count  418.000000  418.000000
# mean    35.184211    1.133971
# std     55.846244    0.580452
# min      0.000000    0.000000
# 25%      7.000000    1.000000
# 50%     14.000000    1.000000
# 75%     31.000000    1.000000
# ...

# %% [markdown]
# <center> <h4> <b> Data visualization </h4> </b> </center>

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize =(10, 7))
survived_count = len(df[df['Survived'] == 1])
not_survived_count = len(df[df['Survived'] == 0])
plt.hist(x = [df[df['Survived']==1]['Age'], df[df['Survived']==0]['Age']],stacked=True, color = ['lightgreen','yellow'],label=[f'Survived ({survived_count})', f'Not Survived ({not_survived_count})'],)
plt.title('Age Histogram with Survival')
plt.xlabel('Age')
plt.ylabel('No of passengers')
plt.legend()

# %%
fig = plt.figure(figsize =(10, 7))
survived_count = len(df[df['Survived'] == 1])
not_survived_count = len(df[df['Survived'] == 0])
plt.hist(x = [df[df['Survived']==1]['Fare'], df[df['Survived']==0]['Fare']], stacked=True, color = ['lightgreen','pink'],label=[f'Survived ({survived_count})', f'Not Survived ({not_survived_count})'],)
plt.title('Fare Histogram with Survival')
plt.xlabel('Fare')
plt.ylabel('No of passengers')
plt.legend()

# %% [markdown]
# <center> <h4> <b> 266 Passenger not survived in the Titanic and 156 survived. </b> </h4> </center>

# %%
column = 'Survived'

sns.set_palette("pastel")
plt.figure(figsize=(8, 6))  

survival_counts = df[column].value_counts()
ax = sns.barplot(x=survival_counts.index, y=survival_counts.values)

# Adding labels and title
plt.xlabel('Survived')
plt.ylabel('Count')
plt.title('Survival Count (0 = No, 1 = Yes)')

# Adding labels on top of bars
for p in ax.patches:
    ax.annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='bottom', color='black', fontsize=12, weight='light')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# <center> <h4> <b> Spliting data </b> </h4> </center>

# %%
from sklearn.model_selection import train_test_split


Train = df.drop(['Survived'], axis=1)
Test = df.iloc[:,1]
x_train, x_test, y_train, y_test = train_test_split(Train, Test, test_size = 0.2, random_state = 1)

# %% [markdown]
# <center> <h4><b> Model building </b></h4> </center>

# %%
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression


LR = LogisticRegression(solver='liblinear', max_iter=200)
LR.fit(x_train, y_train)
y_pred = LR.predict(x_test)
LRAcc = accuracy_score(y_pred,y_test)
print('Logistic regression accuracy: {:.2f}%'.format(LRAcc*100))
# Out:
# Logistic regression accuracy: 92.86%

# %%
import webbrowser

url = "https://anxenown.github.io/CodSoft/Task1_CodSoft/web/index.html"
webbrowser.open(url)
# Out:
# True
